# %%
import pickle

# Load the params.pkl file
file_path = './checkpoint/RFI_complex_a0.5/params.pkl'

with open(file_path, 'rb') as file:
    params = pickle.load(file)

# Modify the dataset parameter
params['dataset'] = './dataset'

# Save the updated parameters back to the file
with open(file_path, 'wb') as file:
    pickle.dump(params, file)

print("Dataset path updated successfully!")
# Out:
# Dataset path updated successfully!
