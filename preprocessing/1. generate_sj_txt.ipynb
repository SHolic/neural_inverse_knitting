# %%
import re
from collections import Counter

# %% [markdown]
# ## 读取原始数据

# %%
names = ['train', 'val', 'test']
real_all = []
synt_all = []
for name in names:
    real_file = f'../dataset/{name}_real.txt'
    with open(real_file, 'r') as f:
        real = []
        for line in f:
            if line.strip().endswith('_back'):
                continue
            real.append(line.strip())
    real_all += real
     
    synt_file = f'../dataset/{name}_synt.txt'
    with open(synt_file, 'r') as f:
        synt = []
        for line in f:
            if line.strip().endswith('_back'):
                continue
            line = line.strip().replace('_front', '')
            synt.append(line)
    synt_all += synt

# %%
print(len(real_all))
print(len(set(real_all)))
print(len(synt_all))
print(len(set(synt_all)))
# Out:
# 1043
# 1043
# 12550
# 12403

# %% [markdown]
# ## 原始分布

# %%
reals = [line.split('_')[0] for line in set(real_all)]
Counter(reals)
# Out:
# Counter({'Mesh': 122,
#          'Move2': 138,
#          'Tuck': 167,
#          'Cable1': 69,
#          'Cable2': 71,
#          'Move1': 114,
#          'Hem': 134,
#          'Miss': 65,
#          'Links1': 42,
#          'Links2': 105,
#          'Full': 16})

# %%
synts = [line.split('_')[0] for line in set(synt_all)]
Counter(synts)
# Out:
# Counter({'Miss': 1419,
#          'Cable1': 1312,
#          'Links2': 981,
#          'Move2': 2858,
#          'Hem': 2686,
#          'Cable2': 829,
#          'Mesh': 229,
#          'Move1': 1522,
#          'Links1': 261,
#          'Tuck': 303,
#          'Full': 3})

# %%
synt_match = []
for line in set(synt_all):
    if line in set(real_all) or line+'_front' in set(real_all):
        synt_match.append(line)

# %%
len(synt_match)
# Out:
# 988

# %%
synt_matchs = [line.split('_')[0] for line in set(synt_match)]
Counter(synt_matchs)
# Out:
# Counter({'Hem': 134,
#          'Move1': 98,
#          'Cable2': 71,
#          'Move2': 114,
#          'Tuck': 167,
#          'Mesh': 122,
#          'Cable1': 69,
#          'Links2': 105,
#          'Miss': 65,
#          'Links1': 42,
#          'Full': 1})

# %% [markdown]
# ## 增加非real

# %%
residuals = dict()
for k, v in Counter(synt_matchs).items():
    if k == 'Full':
        continue
    resi = min(300 - v, Counter(synts)[k] - v)
    residuals[k] = resi
residuals
# Out:
# {'Hem': 166,
#  'Move1': 202,
#  'Cable2': 229,
#  'Move2': 186,
#  'Tuck': 133,
#  'Mesh': 107,
#  'Cable1': 231,
#  'Links2': 195,
#  'Miss': 235,
#  'Links1': 219}

# %%
synt_tmp = [line for line in synt_match if not line.startswith('Full')]
for cat in residuals.keys():
    total = residuals[cat]
    i = 0
    for line in set(synt_all):
        if line not in synt_match and line.startswith(cat) and i < total:
            synt_tmp.append(line)
            i += 1

# %%
len(synt_tmp)
# Out:
# 2890

# %%
synt_tmps = [line.split('_')[0] for line in set(synt_tmp)]
Counter(synt_tmps)
# Out:
# Counter({'Hem': 300,
#          'Move1': 300,
#          'Miss': 300,
#          'Cable1': 300,
#          'Links2': 300,
#          'Move2': 300,
#          'Cable2': 300,
#          'Mesh': 229,
#          'Tuck': 300,
#          'Links1': 261})

# %% [markdown]
# ## 凑到3000个

# %%
print(3000 - len(synt_tmp))
# Out:
# 110

# %%
res2 = {
    'Cable1': 15,
    'Hem': 16,
    'Miss': 15,
    'Move2': 16,
    'Links2': 15,
    'Move1': 15,
    'Mesh': 0,
    'Cable2': 15,
    'Links1': 0,
    'Tuck': 3
}

# %%
synt_final = synt_tmp.copy()
for cat in res2.keys():
    total = res2[cat]
    i = 0
    for line in set(synt_all):
        if line not in synt_tmp and line.startswith(cat) and i < total:
            synt_final.append(line)
            i += 1
len(synt_final)
# Out:
# 3000

# %%
real_final = []
for line in real_all:
    if not line.startswith('Full') and (line in synt_match or line.replace('_front', '') in synt_match):
        real_final.append(line)
len(real_final)
# Out:
# 987

# %%
inst_tmp = [line.replace('_front', '') for line in real_final]
resi3 = [line for line in synt_final if not line in inst_tmp]
inst_final = real_final + resi3
len(inst_final)
# Out:
# 3000

# %%
inst_final
# Out:
# ['Cable1_004_0_12_front',
#  'Cable1_005_0_0',
#  'Cable1_010_0_0_front',
#  'Cable1_014_0_15_front',
#  'Cable1_019_0_10_front',
#  'Cable1_019_0_19',
#  'Cable1_022_0_0_front',
#  'Cable1_025_0_16_front',
#  'Cable1_030_0_7_front',
#  'Cable1_034_0_0',
#  'Cable1_035_0_10',
#  'Cable1_035_0_19_front',
#  'Cable1_038_0_0',
#  'Cable1_040_0_0',
#  'Cable1_043_0_16',
#  'Cable1_047_0_10',
#  'Cable1_049_18_27_front',
#  'Cable1_049_18_32_front',
#  'Cable1_049_9_0_front',
#  'Cable1_049_9_17_front',
#  'Cable1_049_9_32_front',
#  'Cable1_052_11_0_front',
#  'Cable1_054_0_0',
#  'Cable1_055_0_0',
#  'Cable1_068A_0_30_front',
#  'Cable1_068A_6_17_front',
#  'Cable1_069A_21_0_front',
#  'Cable1_069A_22_20_front',
#  'Cable1_069A_31_10_front',
#  'Cable1_069A_6_10_front',
#  'Cable1_082_0_12_front',
#  'Cable1_083A_12_0_front',
#  'Cable1_083A_12_6_front',
#  'Cable1_085_0_0_front',
#  'Cable1_085_0_16_front',
#  'Cable1_085_7_16_front',
#  'Cable1_086_17_12_front',
#  'Cable1_086_17_28_front',
#  'Cable1_086_17_33_front',
#  'Cable1_086_9_24_front',
#  'Cable1_086_9_28_front',
#  'Cable1_086_9_6_front',
#  'Cable1_087_0_0_front',
#  'Cable1_087_0_7_front',
#  'Cable1_101_12_12_front',
#  'Cable2_002_0_0_front',
#  'Cable2_002A_0_0_front',
#  'Cable2_002A_0_13_front',
#  'Cable2_004_0_0',
#  'Cable2_004_0_7_front',
#  'Cable2_006_0_7_front',
#  'Cable2_007A_0_13_front',
#  'Cable2_010_0_10',
#  'Cable2_010_0_18_front',
#  'Cable2_011_0_0',
#  'Cable2_011_0_10_front',
#  'Cable2_012_0_0_front',
#  'Cable2_012_0_7_front',
#  'Cable2_013A_0_9_front',
#  'Cable2_017_0_0',
#  'Cable2_019_0_19_front',
#  'Cable2_020_0_36_front',
#  'Cable2_021_0_8_front',
#  'Cable2_023_0_0_front',
#  'Cable2_026_0_0',
#  'Cable2_027A_0_9_front',
#  'Cable2_028_0_26_front',
#  'Cable2_028_0_39_front',
#  'Cable2_029A_0_16_front',
#  'Cable2_030_0_0_front',
#  'Cable2_030_0_17_front',
#  'Cable2_030_0_31_front',
#  'Cable2_031_0_11_front',
#  'Cable2_031_0_27_front',
#  'Cable2_031_0_6_front',
#  'Cable2_031A_0_11_front',
#  'Cable2_039_0_0_front',
#  'Cable2_039_12_6_front',
#  'Cable2_039_6_0_front',
#  'Cable2_039_6_12_front',
#  'Cable2_042_0_0',
#  'Cable2_044_0_7_front',
#  'Cable2_044_14_7_front',
#  'Cable2_044_7_13_front',
#  'Cable2_044_7_39_front',
#  'Cable2_044A_0_33_front',
#  'Cable2_044A_14_13_front',
#  'Cable2_045_0_10_front',
#  'Cable2_045_7_19_front',
#  'Cable2_046_16_0_front',
#  'Cable2_050_0_0_front',
#  'Cable2_050_0_8_front',
#  'Cable2_054_0_13_front',
#  'Cable2_055_0_0_front',
#  'Cable2_055_0_12_front',
#  'Cable2_055_0_23_front',
#  'Cable2_061A_0_24_front',
#  'Cable2_061A_0_6_front',
#  'Cable2_063_0_18_front',
#  'Cable2_065_18_14_front',
#  'Cable2_066_18_0_front',
#  'Cable2_068_0_12',
#  'Cable2_068_0_7_front',
#  'Hem_037A_36_32_front',
#  'Hem_039A_0_12_front',
#  'Hem_039A_0_42_front',
#  'Hem_039A_13_54_front',
#  'Hem_039A_13_78_front',
#  'Hem_039A_26_54',
#  'Hem_039A_26_6',
#  'Hem_039A_26_84',
#  'Hem_039A_33_0',
#  'Hem_041_27_26_front',
#  'Hem_041_27_7',
#  'Hem_041_34_7',
#  'Hem_043_15_39_front',
#  'Hem_043_30_30_front',
#  'Hem_043_38_20_front',
#  'Hem_043_8_49_front',
#  'Hem_043_8_77',
#  'Hem_043_8_78_front',
#  'Hem_043_90_30_front',
#  'Hem_043_98_0_front',
#  'Hem_043_98_20_front',
#  'Hem_043_98_40_front',
#  'Hem_044_0_52_front',
#  'Hem_044_0_72_front',
#  'Hem_044_0_86_front',
#  'Hem_044_17_15_front',
#  'Hem_044_9_59_front',
#  'Hem_045_9_52_front',
#  'Hem_046_26_56_front',
#  'Hem_046_34_49_front',
#  'Hem_046_51_42_front',
#  'Hem_046_51_75_front',
#  'Hem_046_67_7_front',
#  'Hem_046_68_70_front',
#  'Hem_046_76_56_front',
#  'Hem_046_76_75_front',
#  'Hem_046_77_63_front',
#  'Hem_046_77_70_front',
#  'Hem_046_85_49_front',
#  'Hem_047_0_42_front',
#  'Hem_047_0_58_front',
#  'Hem_047_0_6_front',
#  'Hem_047_10_11_front',
#  'Hem_047_10_22_front',
#  'Hem_047_30_128_front',
#  'Hem_047_30_91_front',
#  'Hem_047_40_80_front',
#  'Hem_047_50_48_front',
#  'Hem_047_50_68_front',
#  'Hem_047_50_79_front',
#  'Hem_047_60_79_front',
#  'Miss_003_0_0',
#  'Miss_004_0_0',
#  'Miss_007_0_0',
#  'Miss_009_0_12_front',
#  'Miss_010_6_6',
#  'Miss_012_0_15',
#  'Miss_012_0_8_front',
#  'Miss_013_0_6',
#  'Miss_015_0_7_front',
#  'Miss_015_7_13',
#  'Miss_024_0_41_front',
#  'Miss_025_18_0_front',
#  'Miss_025_24_14_front',
#  'Miss_029A_0_12',
#  'Miss_031A_15_18',
#  'Miss_034A_0_11',
#  'Miss_042A_0_6',
#  'Miss_042A_10_12',
#  'Miss_053_15_0_front',
#  'Miss_054_22_15_front',
#  'Miss_054_22_8_front',
#  'Miss_054_28_29_front',
#  'Miss_054_6_15_front',
#  'Miss_055_13_0',
#  'Miss_055_13_6_front',
#  'Miss_056_0_0_front',
#  'Miss_056_18_0_front',
#  'Miss_057_11_0_front',
#  'Miss_057_11_10_front',
#  'Miss_057_17_40_front',
#  'Miss_060_17_0_front',
#  'Miss_060_17_25_front',
#  'Miss_060_22_0_front',
#  'Miss_060_28_38',
#  'Miss_061_7_0_front',
#  'Miss_062_0_0_front',
#  'Miss_Border008_0_15',
#  'Miss_Border012_0_12_front',
#  'Miss_Border014_0_6',
#  'Miss_Border018_6_13_front',
#  'Miss_Border020_0_16_front',
#  'Miss_Border025_0_30_front',
#  'Miss_Border025_6_26_front',
#  'Miss_Border026_6_0_front',
#  'Miss_Border027_10_20_front',
#  'Miss_Border027_19_6_front',
#  'Miss_Border030_0_0',
#  'Miss_Border030_15_0',
#  'Miss_Border030_8_0_front',
#  'Miss_Border035_16_0_front',
#  'Miss_Border037_21_26_front',
#  'Miss_Border037_27_31_front',
#  'Miss_Border038_0_0_front',
#  'Miss_Border046_17_9_front',
#  'Miss_Border047_18_6_front',
#  'Miss_Border050_0_0_front',
#  'Miss_Border054_12_0_front',
#  'Miss_Border054A_7_6_front',
#  'Move1_003A_12_12',
#  'Move1_004_0_0',
#  'Move1_005_0_0',
#  'Move1_011_0_0',
#  'Move1_016A_0_7',
#  'Move1_022_6_12_front',
#  'Move1_025A_0_0_front',
#  'Move1_027A_13_16_front',
#  'Move1_Bias05A_0_10',
#  'Move1_Bias06_0_0',
#  'Move1_Bias08_0_7',
#  'Move1_Bias11_0_20_front',
#  'Move1_Bias11A_0_0',
#  'Move1_Bias13A_0_18',
#  'Move1_Bias14_0_7',
#  'Move1_Bias15_0_12_front',
#  'Move1_Bias16_0_8_front',
#  'Move1_Bias16A_0_8_front',
#  'Move1_Bias21_8_0_front',
#  'Move1_Bias23_0_21_b_front',
#  'Move1_Bias23_0_21_front',
#  'Move1_Bias23A_0_21_front',
#  'Move1_Bias24_9_35_front',
#  'Move1_Bias24_9_7_front',
#  'Move1_Bias29A_0_0',
#  'Move1_Bias29A_0_9_front',
#  'Move1_Bias29A_12_17_b_front',
#  'Move1_Bias31A_0_20',
#  'Move1_Bias33_0_7_front',
#  'Move1_Bias34_0_0_front',
#  'Move1_Bias35A_8_12_front',
#  'Move1_Diamond04_6_0_front',
#  'Move1_Diamond05_0_0_front',
#  'Move1_Diamond10_0_17',
#  'Move1_Diamond12A_0_30_front',
#  'Move1_Diamond12A_17_6_front',
#  'Move1_Diamond12A_26_20_front',
#  'Move1_Diamond12A_30_11_b_front',
#  'Move1_Diamond12A_30_11_front',
#  'Move1_Diamond13A_0_0_b_front',
#  'Move1_Diamond13A_0_0_front',
#  'Move1_Diamond18_0_0_front',
#  'Move1_Diamond18_12_0_front',
#  'Move1_Diamond18A_7_33_front',
#  'Move1_Diamond19A_12_0_front',
#  'Move1_Diamond20_12_8_front',
#  'Move1_Diamond20A_12_16',
#  'Move1_Diamond23_0_16',
#  'Move1_Diamond24A_8_16',
#  'Move1_Diamond26A_6_6_front',
#  'Move1_Diamond30_6_35_front',
#  'Move1_Diamond30A_6_23_front',
#  'Move1_Diamond34_10_0_front',
#  'Move1_Diamond34_10_6_front',
#  'Move1_Diamond34A_19_21_front',
#  'Move1_Diamond38A_0_10',
#  'Move1_Diamond41_10_27_front',
#  'Move1_Diamond41A_0_17_front',
#  'Move1_Diamond43A_0_8_front',
#  'Move1_Diamond44A_0_13',
#  'Move1_Diamond45_0_31_front',
#  'Move1_Diamond47_0_7_b_front',
#  'Move1_Diamond47_0_7_front',
#  'Move1_Diamond49_14_12_front',
#  'Move1_Diamond49A_8_7',
#  'Move1_Diamond50_0_10',
#  'Move1_Diamond51_0_0',
#  'Move1_Diamond52_0_15_front',
#  'Move1_Diamond52_0_43_front',
#  'Move1_Diamond52_8_15_front',
#  'Move1_Diamond53_0_20_front',
#  'Move1_Leaf05A_12_10_front',
#  'Move1_Zigzag04_12_0_front',
#  'Move1_Zigzag04A_0_10_front',
#  'Move1_Zigzag07A_0_0',
#  'Move1_Zigzag10A_0_0',
#  'Move1_Zigzag13A_12_16',
#  'Move1_Zigzag15_0_30_front',
#  'Move1_Zigzag15_18_22_front',
#  'Move1_Zigzag16_0_0_front',
#  'Move2_003A_0_0_front',
#  'Move2_003A_0_7',
#  'Move2_004_0_0',
#  'Move2_006_0_0',
#  'Move2_007_10_0_front',
#  'Move2_014A_0_12',
#  'Move2_027A_9_0_front',
#  'Move2_028A_8_15',
#  'Move2_029_7_9_front',
#  'Move2_029A_0_9',
#  'Move2_030_0_15_front',
#  'Move2_034A_0_7_front',
#  'Move2_041_0_0',
#  'Move2_047A_0_0',
#  'Move2_053A_0_0',
#  'Move2_056_0_12',
#  'Move2_062B_19_22_front',
#  'Move2_065_0_0_front',
#  'Move2_073A_0_0',
#  'Move2_076A_0_0',
#  'Move2_078A_7_7_front',
#  'Move2_079A_15_0_front',
#  'Move2_079A_8_15_front',
#  'Move2_088A_0_7_front',
#  'Move2_089_0_16_front',
#  'Move2_094_10_0_front',
#  'Move2_095_7_18',
#  'Move2_096_0_10_front',
#  'Move2_101A_16_18_front',
#  'Move2_103A_7_0_front',
#  'Move2_105A_0_10_front',
#  'Move2_105A_17_0_front',
#  'Move2_105A_32_20_front',
#  'Move2_107A_0_17_front',
#  'Move2_108_8_15_front',
#  'Move2_110_0_6_front',
#  'Move2_111_42_6_front',
#  'Move2_111_7_30_front',
#  'Move2_113_18_8_b_front',
#  'Move2_113_18_8_front',
#  'Move2_114_7_22_front',
#  'Move2_115_0_20_front',
#  'Move2_115_7_17_b_front',
#  'Move2_115_7_17_front',
#  'Move2_116_0_8_front',
#  'Move2_117_31_10_front',
#  'Move2_117_31_30_b_front',
#  'Move2_117_36_48',
#  'Move2_117_7_40_front',
#  'Move2_117_7_48_front',
#  'Move2_124_12_0_front',
#  'Move2_126_7_22_front',
#  'Move2_128_17_11_front',
#  'Move2_128_17_31_front',
#  'Move2_129_0_16',
#  'Move2_130_6_0',
#  'Move2_131_7_0_front',
#  'Move2_132_0_21_front',
#  'Move2_133_16_18_front',
#  'Move2_134_12_14_front',
#  'Move2_137_21_34_front',
#  'Move2_137_27_34_front',
#  'Move2_139_8_31_front',
#  'Move2_Miss02_0_0',
#  'Move2_Motif09A_9_6_front',
#  'Move2_Motif13_40_28_front',
#  'Move2_Motif14_31_32_front',
#  'Move2_Motif14_7_38_front',
#  'Move2_Motif15_0_18_front',
#  'Move2_Motif15_0_24_front',
#  'Move2_Motif20_17_0_front',
#  'Move2_Motif22A_9_18_front',
#  'Move2_Motif23_23_33_front',
#  'Move2_Motif23_29_26_front',
#  'Move2_Motif25A_0_8_front',
#  'Move2_Motif25B_8_0_front',
#  'Move2_Motif28A_10_18_front',
#  'Move2_Motif29A_0_6_front',
#  'Move2_Motif32_14_13_front',
#  'Move2_Motif32_39_20_front',
#  'Move2_Motif32_7_26_front',
#  'Move2_Motif34_15_18_front',
#  'Move2_Motif34_23_29_front',
#  'Move2_Motif34_23_63_front',
#  'Move2_Motif34_23_6_front',
#  'Move2_Motif34_38_18_front',
#  'Move2_Motif34_38_51_front',
#  'Move2_Motif34_38_57_front',
#  'Move2_Motif34_53_0_front',
#  'Move2_Motif34_60_58_front',
#  'Move2_Motif34_67_47_front',
#  'Move2_Motif34_75_12_front',
#  'Move2_Motif34_75_45_front',
#  'Move2_Motif34_82_45_front',
#  'Move2_Motif34_82_69_front',
#  'Move2_Motif34_88_46_front',
#  'Move2_Motif34_88_6_front',
#  'Move2_Motif34_89_23_front',
#  'Move2_Motif34_89_35_front',
#  'Tuck_001_0_0',
#  'Tuck_002A_0_0_front',
#  'Tuck_003_0_0_front',
#  'Tuck_003_0_11',
#  'Tuck_003_0_6_front',
#  'Tuck_004_0_0_front',
#  'Tuck_005_0_0',
#  'Tuck_007A_0_0',
#  'Tuck_008A_0_0',
#  'Tuck_010A_0_0',
#  'Tuck_011A_0_0_front',
#  'Tuck_012A_0_0_front',
#  'Tuck_012A_0_13_front',
#  'Tuck_012A_0_7',
#  'Tuck_013A_0_0_front',
#  'Tuck_013A_0_14_front',
#  'Tuck_013A_0_8',
#  'Tuck_014_0_12_front',
#  'Tuck_015A_0_0_front',
#  'Tuck_015A_0_10_front',
#  'Tuck_016A_0_0_front',
#  'Tuck_016A_0_14_front',
#  'Tuck_016A_0_7_front',
#  'Tuck_016B_0_0_front',
#  'Tuck_016B_0_14_front',
#  'Tuck_016B_0_7_front',
#  'Tuck_019_0_0_front',
#  'Tuck_019_0_6_front',
#  'Tuck_020_0_12_front',
#  'Tuck_020_0_7_front',
#  'Tuck_021A_0_8_front',
#  'Tuck_022_0_0',
#  'Tuck_022_0_14_front',
#  'Tuck_022_0_7_front',
#  'Tuck_023_0_0_front',
#  'Tuck_023_0_13_front',
#  'Tuck_023_0_20_front',
#  'Tuck_023_0_26_front',
#  'Tuck_023_0_39_front',
#  'Tuck_023_0_7_front',
#  'Tuck_023A_0_0_front',
#  'Tuck_023A_0_39_front',
#  'Tuck_024_0_12_front',
#  'Tuck_024_0_7_front',
#  'Tuck_024A_0_0_front',
#  'Tuck_024A_0_12_front',
#  'Tuck_026_0_0',
#  'Tuck_026_0_20_front',
#  'Tuck_027_0_0_front',
#  'Tuck_027_0_16_front',
#  'Tuck_027_0_8_front',
#  'Tuck_028A_0_0_front',
#  'Tuck_028A_0_17_front',
#  'Tuck_028A_0_9_front',
#  'Tuck_029A_0_0_front',
#  'Tuck_029A_0_9_front',
#  'Tuck_029A_11_18_front',
#  'Tuck_029A_11_9_front',
#  'Tuck_029A_6_0_front',
#  'Tuck_029A_6_18_front',
#  'Tuck_030_0_0_front',
#  'Tuck_030_0_16_front',
#  'Tuck_030_0_9_front',
#  'Tuck_030_11_0_front',
#  'Tuck_030_6_16_front',
#  'Tuck_030_6_9_front',
#  'Tuck_031_0_0',
#  'Tuck_031_0_12_front',
#  'Tuck_031_0_7_front',
#  'Tuck_032_0_0',
#  'Tuck_033_0_8',
#  'Tuck_036_7_20',
#  'Tuck_038_0_11_front',
#  'Tuck_038_0_17_front',
#  'Tuck_038_0_22_front',
#  'Tuck_038_0_28_front',
#  'Tuck_038_0_33_front',
#  'Tuck_038_0_6_front',
#  'Tuck_038_14_17_front',
#  'Tuck_038_14_22_front',
#  'Tuck_038_14_28_front',
#  'Tuck_038_8_11_front',
#  'Tuck_038_8_28_front',
#  'Tuck_038_8_33_front',
#  'Tuck_038_8_6_front',
#  'Tuck_038A_0_0_front',
#  'Tuck_038A_0_11_front',
#  'Tuck_038A_0_17',
#  'Tuck_038A_0_22_front',
#  'Tuck_038A_0_28_front',
#  'Tuck_038A_14_0_front',
#  'Tuck_038A_14_11_front',
#  'Tuck_038A_14_17_front',
#  'Tuck_038A_14_28_front',
#  'Tuck_038A_14_6_front',
#  'Tuck_038A_8_11_front',
#  'Tuck_038A_8_22_front',
#  'Tuck_038A_8_28_front',
#  'Tuck_038A_8_33_front',
#  'Tuck_038A_8_6_front',
#  'Tuck_039_0_0_front',
#  'Tuck_039_0_11_front',
#  'Tuck_039_0_17_front',
#  'Tuck_039_0_28_front',
#  'Tuck_039_0_33_front',
#  'Tuck_039_0_6_front',
#  'Tuck_039_14_0_front',
#  'Tuck_039_14_11_front',
#  'Tuck_039_14_17_front',
#  'Tuck_039_14_33_front',
#  'Tuck_039_14_6_front',
#  'Tuck_039_8_22_front',
#  'Tuck_039_8_28_front',
#  'Tuck_039A_0_22_front',
#  'Tuck_039A_0_33_front',
#  'Tuck_039A_14_0_front',
#  'Tuck_039A_14_11_front',
#  'Tuck_039A_14_17_front',
#  'Tuck_039A_14_22_front',
#  'Tuck_039A_14_28_front',
#  'Tuck_039A_14_33_front',
#  'Tuck_039A_14_6_front',
#  'Tuck_039A_8_11_front',
#  'Tuck_039A_8_17_front',
#  'Tuck_039A_8_33_front',
#  'Tuck_040A_0_0_front',
#  'Tuck_040A_0_18_front',
#  'Tuck_040A_0_9_front',
#  'Tuck_040A_7_0_front',
#  'Tuck_040A_7_18_front',
#  'Tuck_040A_7_9_front',
#  'Tuck_041A_0_9_front',
#  'Tuck_041A_12_0_front',
#  'Tuck_041A_12_16_front',
#  'Tuck_041A_12_9_front',
#  'Tuck_041A_6_0_front',
#  'Tuck_041A_6_16_front',
#  'Tuck_041A_6_9_front',
#  'Tuck_042_0_6_front',
#  'Cable1_029_0_0',
#  'Cable1_068A_6_20_front',
#  'Cable1_101_6_0_front',
#  'Cable1_049_9_27_front',
#  'Cable1_025_0_0_front',
#  'Cable1_018_0_0_front',
#  'Cable1_069A_21_10_front',
#  'Cable1_049_18_17_front',
#  'Cable1_028_0_0_front',
#  'Cable2_001A_0_13_front',
#  'Cable2_006_0_13',
#  'Cable2_046_16_9',
#  'Cable2_054_0_39_front',
#  'Hem_044_26_37',
#  'Hem_043_45_98_front',
#  'Hem_054_23_55_front',
#  'Hem_043_98_79_front',
#  'Hem_046_51_14_front',
#  'Hem_048_12_9_front',
#  'Links1_007_0_0',
#  'Links1_006_0_6_front',
#  'Links1_044_0_8_front',
#  'Links2_018_0_7_front',
#  'Links2_022_0_6_front',
#  'Links2_018_0_0_front',
#  'Links2_049_27_17_front',
#  'Links2_031_10_22_front',
#  'Mesh_007_0_0_front',
#  'Mesh_024_0_13_front',
#  'Mesh_005A_0_0_front',
#  'Mesh_024A_19_13_front',
#  'Mesh_022A_0_6_front',
#  'Mesh_023A_9_41_front',
#  'Miss_027A_15_0_front',
#  'Miss_031A_8_0_front',
#  'Miss_025A_36_0_front',
#  'Move1_Diamond15A_0_15',
#  'Move1_Bias29A_12_17_front',
#  'Move1_Diamond30A_0_18_front',
#  'Move1_Diamond17A_12_7_front',
#  'Move1_Bias04_0_6_front',
#  'Move2_129_6_16_front',
#  'Move2_105A_32_0_front',
#  'Tuck_039A_0_11_front',
#  'Tuck_023A_0_13_front',
#  'Tuck_038_14_11_front',
#  'Tuck_039A_0_6_front',
#  'Tuck_039_8_17_front',
#  'Cable1_033_0_17_front',
#  'Cable2_030_0_11_front',
#  'Hem_045_18_37_front',
#  'Move2_Motif34_68_45_front',
#  'Mesh_022_0_11_front',
#  'Tuck_009A_0_0',
#  'Hem_053_0_11',
#  'Cable2_007A_0_7_front',
#  'Move2_003A_0_12_front',
#  'Tuck_023A_0_33_front',
#  'Hem_050_49_48_front',
#  'Cable2_020_0_20_front',
#  'Mesh_024A_19_0_front',
#  'Move2_139_30_13_front',
#  'Hem_047_40_126_front',
#  'Tuck_039A_8_28_front',
#  'Cable1_068A_0_22_front',
#  'Cable1_062_11_0_front',
#  'Links2_021_7_7_front',
#  'Mesh_022_7_6_front',
#  'Cable1_069A_0_20_front',
#  'Tuck_039A_8_22_front',
#  'Links2_006_0_7_front',
#  'Tuck_024A_0_6_front',
#  'Mesh_024_0_7_front',
#  'Cable1_033_0_22_front',
#  'Cable1_049_0_22_front',
#  'Move1_Bias26A_0_10',
#  'Move1_022A_13_0',
#  'Tuck_024_0_0_front',
#  'Tuck_038A_0_6_front',
#  'Hem_047_20_0_front',
#  'Hem_046_60_63_front',
#  'Mesh_022_7_30_front',
#  'Move1_Diamond48A_9_30_front',
#  'Links2_004_0_17_front',
#  'Mesh_024_10_0',
#  'Hem_039A_39_60_front',
#  'Hem_048_52_83_front',
#  'Hem_046_77_61_front',
#  'Cable2_035_0_0_front',
#  'Hem_047_50_6_front',
#  'Cable1_086_9_0_front',
#  'Cable2_031A_0_21_front',
#  'Hem_037A_6_0_front',
#  'Mesh_023A_18_41_front',
#  'Hem_043_90_49_front',
#  'Hem_037A_30_31_front',
#  'Mesh_041_0_0',
#  'Move2_Motif14_7_7_front',
#  'Links1_003_0_0',
#  'Tuck_004_0_6_front',
#  'Hem_050_9_54_front',
#  'Move1_Diamond11A_0_7',
#  'Move1_Leaf05A_0_20_front',
#  'Links2_025_0_21_front',
#  'Tuck_020_0_0_front',
#  'Links2_022_27_6_front',
#  'Cable1_009_0_0',
#  'Cable2_014_0_30_front',
#  'Tuck_041A_0_16_front',
#  'Miss_031A_8_18',
#  'Move1_Bias35A_14_0_front',
#  'Move1_Diamond05_0_10_front',
#  'Tuck_023_0_33_front',
#  'Move2_114_20_6_front',
#  'Links2_019_0_16_front',
#  'Links2_014_0_22_front',
#  'Move2_044A_8_0',
#  'Cable1_069A_21_20_front',
#  'Mesh_008_0_0',
#  'Hem_046_110_0_front',
#  'Cable1_069A_31_0_front',
#  'Move2_117_31_30_front',
#  'Cable2_006_0_0_front',
#  'Move1_Diamond49_14_12_b_front',
#  'Hem_050_17_82_front',
#  'Mesh_024A_19_37_front',
#  'Move1_Diamond22_8_9',
#  'Tuck_023A_0_20_front',
#  'Cable1_014_0_0_front',
#  'Cable2_049A_6_18_front',
#  'Cable2_015A_0_0_front',
#  'Tuck_039A_0_0_front',
#  'Mesh_006_0_0',
#  'Tuck_038_14_0_front',
#  'Tuck_038A_0_33_front',
#  'Links1_024_0_6_front',
#  'Move1_009_7_0',
#  'Links2_016_8_17_front',
#  'Miss_011_0_6',
#  'Move2_032A_10_0_front',
#  'Hem_045_0_8',
#  'Move2_107A_7_0',
#  'Hem_044_0_29_front',
#  'Move2_002A_0_7',
#  'Links2_022_27_24_front',
#  'Mesh_023_0_7_front',
#  'Tuck_039_14_22_front',
#  'Mesh_023A_18_7_front',
#  'Cable1_069A_31_20_front',
#  'Mesh_022A_12_26_front',
#  'Cable1_028_0_14_front',
#  'Links2_008_8_9_front',
#  'Mesh_003_0_0_front',
#  'Links2_032_0_8_front',
#  'Links2_017_12_22_front',
#  'Tuck_038A_14_33_front',
#  'Links1_054_0_12_front',
#  'Mesh_022A_7_11_front',
#  'Links1_029_0_0_front',
#  'Mesh_023A_0_41_front',
#  'Tuck_038_8_0_front',
#  'Hem_047_30_101_front',
#  'Links1_036_0_0_front',
#  'Move2_Motif30A_6_35_front',
#  'Cable1_062_6_12_front',
#  'Move2_Motif29A_0_18_front',
#  'Hem_047_40_73_front',
#  'Move1_Diamond22_0_9_front',
#  'Tuck_039_14_28_front',
#  'Move1_Bias16A_8_8',
#  'Tuck_041A_0_0_front',
#  'Cable1_101_0_12_front',
#  'Hem_050_42_12_front',
#  'Move1_Diamond04_6_0_b_front',
#  'Tuck_039A_8_0_front',
#  'Hem_045_45_44_front',
#  'Move2_Motif34_74_57_front',
#  'Tuck_014_0_7',
#  'Tuck_038A_8_17_front',
#  'Hem_039A_7_42',
#  'Hem_043_38_49',
#  'Hem_046_84_70',
#  'Hem_048_52_99',
#  'Hem_039A_33_72',
#  'Hem_045_0_52',
#  'Hem_048_67_75',
#  'Hem_048_18_26',
#  'Hem_054_38_33',
#  'Hem_047_40_38',
#  'Hem_051_24_108',
#  'Hem_037A_30_39',
#  'Hem_045_36_66',
#  ...]

# %%
# with open('../dataset/inst_test.txt', 'w') as f:
#     for line in inst_final:
#         f.write(line+'\n')

# %% [markdown]
# ## train val split

# %%
with open('../dataset/inst_final.txt', 'r') as f:
    synt_final = []
    for line in f:
        synt_final.append(line.strip())

# %%
val_synt = []
val_synt_cnt = {
    'Cable1': 0,
    'Hem': 0,
    'Miss': 0,
    'Move2': 0,
    'Links2': 0,
    'Move1': 0,
    'Mesh': 0,
    'Cable2': 0,
    'Links1': 0,
    'Tuck': 0
}

for line in synt_final:
    cat = line.split('_')[0]
    if val_synt_cnt[cat] < 30:
        val_synt.append(line)
        val_synt_cnt[cat] += 1
        
train_synt = [line for line in synt_final if line not in val_synt]
print(len(train_synt))
print(len(val_synt))
# Out:
# 2700
# 300

# %%
with open('../dataset/train_synt.txt', 'w') as f:
    for line in train_synt:
        f.write(line+'\n')
        
with open('../dataset/val_synt.txt', 'w') as f:
    for line in val_synt:
        f.write(line+'\n')
        
with open('../dataset/train_unsup.txt', 'w') as f:
    pass

with open('../dataset/train_real.txt', 'w') as f:
    for line in train_synt:
        f.write(line+'\n')

with open('../dataset/val_real.txt', 'w') as f:
    for line in val_synt:
        f.write(line+'\n')
        
with open('../dataset/train_real.txt', 'w') as f:
    for line in train_synt:
        f.write(line+'\n')

with open('../dataset/val_real.txt', 'w') as f:
    for line in val_synt:
        f.write(line+'\n')
