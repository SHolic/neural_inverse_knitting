# %%
import tensorflow as tf


def variable_count(meta_file):
    # 创建新的图
    graph = tf.Graph()

    with graph.as_default():
        with tf.Session() as sess:
            # 加载 .meta 文件
            saver = tf.train.import_meta_graph(meta_file)

            # 不需要恢复变量的值，因此不需要调用 saver.restore()
            # 如果需要恢复变量值，可以取消注释以下代码，并提供正确的 checkpoint 路径
            # saver.restore(sess, tf.train.latest_checkpoint('./checkpoint/'))

            # 获取所有可训练的变量
            trainable_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES)

            total_params = 0
            for var in trainable_vars:
                shape = var.get_shape()
                var_params = 1
                for dim in shape:
                    var_params *= dim.value
                total_params += var_params
                print("变量名称：{}, 形状：{}, 参数数量：{}".format(var.name, shape, var_params))

            print("模型中可训练变量的总数量：", total_params)

# %%
variable_count('../checkpoint/RFI_complex_a0.5/_lr-0.0005_batch-2/FeedForwardNetworks-150500.meta')
# Out:
# 变量名称：generator/transformer_r2s/resnet1/0/Conv/weights:0, 形状：(3, 3, 1, 64), 参数数量：576
# 变量名称：generator/transformer_r2s/resnet1/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet1/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/0/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/1/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/2/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/3/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/3/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/4/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/5/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/5/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/1/Conv/weights:0, 形状：(3, 3, 128, 64), 参数数量：73728
# 变量名称：generator/transformer_r2s/resnet3/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/2/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet3/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/6/Conv/weights:0, 形状：(1, 1, 64, 1), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/6/Conv/biases:0, 形状：(1,), 参数数量：1
# 变量名称：generator/img2prog/img2feat/0/Conv/weights:0, 形状：(3, 3, 1, 64), 参数数量：576
# 变量名称：generator/img2prog/img2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/img2feat/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/img2feat/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip_reduce/80/Conv/weights:0, 形状：(1, 1, 1024, 64), 参数数量：65536
# 变量名称：generator/img2prog/skip_reduce/80/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip_reduce/40/Conv/weights:0, 形状：(1, 1, 256, 64), 参数数量：16384
# 变量名称：generator/img2prog/skip_reduce/40/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip2feat/0/Conv/weights:0, 形状：(3, 3, 192, 64), 参数数量：110592
# 变量名称：generator/img2prog/skip2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/0/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/0/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/0/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/1/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/1/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/1/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/2/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/2/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/3/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/3/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/3/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/3/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/4/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/4/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/5/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/5/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/5/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/5/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2prog/0/Conv/weights:0, 形状：(3, 3, 128, 64), 参数数量：73728
# 变量名称：generator/img2prog/feat2prog/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2prog/2/Conv/weights:0, 形状：(1, 1, 64, 17), 参数数量：1088
# 变量名称：generator/img2prog/feat2prog/2/Conv/biases:0, 形状：(17,), 参数数量：17
# 变量名称：discriminator/image_domain/conv2d/Conv/weights:0, 形状：(1, 1, 17, 4), 参数数量：68
# 变量名称：discriminator/image_domain/conv2d/Conv/biases:0, 形状：(4,), 参数数量：4
# 变量名称：discriminator/image_domain/d_h0_conv/Conv/weights:0, 形状：(3, 3, 5, 64), 参数数量：2880
# 变量名称：discriminator/image_domain/d_h0_conv/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：discriminator/image_domain/d_h1_conv/Conv/weights:0, 形状：(3, 3, 64, 128), 参数数量：73728
# 变量名称：discriminator/image_domain/d_h1_conv/Conv/biases:0, 形状：(128,), 参数数量：128
# 变量名称：discriminator/image_domain/d_h2_conv/Conv/weights:0, 形状：(3, 3, 128, 256), 参数数量：294912
# 变量名称：discriminator/image_domain/d_h2_conv/Conv/biases:0, 形状：(256,), 参数数量：256
# 变量名称：discriminator/image_domain/d_h3_conv/Conv/weights:0, 形状：(3, 3, 256, 512), 参数数量：1179648
# 变量名称：discriminator/image_domain/d_h3_conv/Conv/biases:0, 形状：(512,), 参数数量：512
# 变量名称：discriminator/image_domain/d_h4_pred/Conv/weights:0, 形状：(3, 3, 512, 1), 参数数量：4608
# 变量名称：discriminator/image_domain/d_h4_pred/Conv/biases:0, 形状：(1,), 参数数量：1
# 变量名称：loss/smoothing/gauss_weight:0, 形状：(11, 11, 1, 1), 参数数量：121
# 变量名称：loss/smoothing_1/gauss_weight:0, 形状：(11, 11, 1, 1), 参数数量：121
# 模型中可训练变量的总数量： 2934605

# %%
variable_count('../checkpoint/RFINet_notran_noaug_newinst/_lr-0.0005_batch-2/FeedForwardNetworks-150002.meta')
# Out:
# 变量名称：generator/transformer_r2s/resnet1/0/Conv/weights:0, 形状：(3, 3, 1, 64), 参数数量：576
# 变量名称：generator/transformer_r2s/resnet1/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet1/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/0/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/1/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/2/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/3/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/3/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/4/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/5/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/5/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/1/Conv/weights:0, 形状：(3, 3, 128, 64), 参数数量：73728
# 变量名称：generator/transformer_r2s/resnet3/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/2/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet3/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/6/Conv/weights:0, 形状：(1, 1, 64, 1), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/6/Conv/biases:0, 形状：(1,), 参数数量：1
# 变量名称：generator/img2prog/img2feat/0/Conv/weights:0, 形状：(3, 3, 1, 64), 参数数量：576
# 变量名称：generator/img2prog/img2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/img2feat/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/img2feat/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip_reduce/80/Conv/weights:0, 形状：(1, 1, 1024, 64), 参数数量：65536
# 变量名称：generator/img2prog/skip_reduce/80/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip_reduce/40/Conv/weights:0, 形状：(1, 1, 256, 64), 参数数量：16384
# 变量名称：generator/img2prog/skip_reduce/40/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip2feat/0/Conv/weights:0, 形状：(3, 3, 192, 64), 参数数量：110592
# 变量名称：generator/img2prog/skip2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/0/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/0/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/0/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/1/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/1/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/1/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/2/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/2/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/3/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/3/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/3/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/3/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/4/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/4/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/5/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/5/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/5/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/5/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2prog/0/Conv/weights:0, 形状：(3, 3, 128, 64), 参数数量：73728
# 变量名称：generator/img2prog/feat2prog/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2prog/2/Conv/weights:0, 形状：(1, 1, 64, 14), 参数数量：896
# 变量名称：generator/img2prog/feat2prog/2/Conv/biases:0, 形状：(14,), 参数数量：14
# 变量名称：discriminator/image_domain/conv2d/Conv/weights:0, 形状：(1, 1, 14, 4), 参数数量：56
# 变量名称：discriminator/image_domain/conv2d/Conv/biases:0, 形状：(4,), 参数数量：4
# 变量名称：discriminator/image_domain/d_h0_conv/Conv/weights:0, 形状：(3, 3, 5, 64), 参数数量：2880
# 变量名称：discriminator/image_domain/d_h0_conv/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：discriminator/image_domain/d_h1_conv/Conv/weights:0, 形状：(3, 3, 64, 128), 参数数量：73728
# 变量名称：discriminator/image_domain/d_h1_conv/Conv/biases:0, 形状：(128,), 参数数量：128
# 变量名称：discriminator/image_domain/d_h2_conv/Conv/weights:0, 形状：(3, 3, 128, 256), 参数数量：294912
# 变量名称：discriminator/image_domain/d_h2_conv/Conv/biases:0, 形状：(256,), 参数数量：256
# 变量名称：discriminator/image_domain/d_h3_conv/Conv/weights:0, 形状：(3, 3, 256, 512), 参数数量：1179648
# 变量名称：discriminator/image_domain/d_h3_conv/Conv/biases:0, 形状：(512,), 参数数量：512
# 变量名称：discriminator/image_domain/d_h4_pred/Conv/weights:0, 形状：(3, 3, 512, 1), 参数数量：4608
# 变量名称：discriminator/image_domain/d_h4_pred/Conv/biases:0, 形状：(1,), 参数数量：1
# 变量名称：loss/smoothing/gauss_weight:0, 形状：(11, 11, 1, 1), 参数数量：121
# 变量名称：loss/smoothing_1/gauss_weight:0, 形状：(11, 11, 1, 1), 参数数量：121
# 模型中可训练变量的总数量： 2934398

# %%
variable_count('../checkpoint/RFINet_complete_MIL/_lr-0.0005_batch-2/FeedForwardNetworks-150000.meta')
# Out:
# 变量名称：generator/transformer_r2s/resnet1/0/Conv/weights:0, 形状：(3, 3, 1, 64), 参数数量：576
# 变量名称：generator/transformer_r2s/resnet1/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet1/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet1/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/0/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/0/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/1/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/1/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/2/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/2/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/3/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/3/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/3/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/4/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/4/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/5/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet2/5/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet2/5/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/1/Conv/weights:0, 形状：(3, 3, 128, 64), 参数数量：73728
# 变量名称：generator/transformer_r2s/resnet3/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/2/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/transformer_r2s/resnet3/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/6/Conv/weights:0, 形状：(1, 1, 64, 1), 参数数量：64
# 变量名称：generator/transformer_r2s/resnet3/6/Conv/biases:0, 形状：(1,), 参数数量：1
# 变量名称：generator/img2prog/img2feat/0/Conv/weights:0, 形状：(3, 3, 1, 64), 参数数量：576
# 变量名称：generator/img2prog/img2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/1/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/img2feat/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/3/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/img2feat/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/img2feat/5/InstanceNorm/beta:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip_reduce/80/Conv/weights:0, 形状：(1, 1, 1024, 64), 参数数量：65536
# 变量名称：generator/img2prog/skip_reduce/80/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip_reduce/40/Conv/weights:0, 形状：(1, 1, 256, 64), 参数数量：16384
# 变量名称：generator/img2prog/skip_reduce/40/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/skip2feat/0/Conv/weights:0, 形状：(3, 3, 192, 64), 参数数量：110592
# 变量名称：generator/img2prog/skip2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/0/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/0/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/0/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/1/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/1/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/1/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/1/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/2/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/2/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/2/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/2/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/3/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/3/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/3/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/3/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/4/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/4/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/4/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/4/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/5/Conv/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/5/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2feat/5/Conv_1/weights:0, 形状：(3, 3, 64, 64), 参数数量：36864
# 变量名称：generator/img2prog/feat2feat/5/Conv_1/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2prog/0/Conv/weights:0, 形状：(3, 3, 128, 64), 参数数量：73728
# 变量名称：generator/img2prog/feat2prog/0/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：generator/img2prog/feat2prog/2/Conv/weights:0, 形状：(1, 1, 64, 34), 参数数量：2176
# 变量名称：generator/img2prog/feat2prog/2/Conv/biases:0, 形状：(34,), 参数数量：34
# 变量名称：discriminator/image_domain/conv2d/Conv/weights:0, 形状：(1, 1, 34, 4), 参数数量：136
# 变量名称：discriminator/image_domain/conv2d/Conv/biases:0, 形状：(4,), 参数数量：4
# 变量名称：discriminator/image_domain/d_h0_conv/Conv/weights:0, 形状：(3, 3, 5, 64), 参数数量：2880
# 变量名称：discriminator/image_domain/d_h0_conv/Conv/biases:0, 形状：(64,), 参数数量：64
# 变量名称：discriminator/image_domain/d_h1_conv/Conv/weights:0, 形状：(3, 3, 64, 128), 参数数量：73728
# 变量名称：discriminator/image_domain/d_h1_conv/Conv/biases:0, 形状：(128,), 参数数量：128
# 变量名称：discriminator/image_domain/d_h2_conv/Conv/weights:0, 形状：(3, 3, 128, 256), 参数数量：294912
# 变量名称：discriminator/image_domain/d_h2_conv/Conv/biases:0, 形状：(256,), 参数数量：256
# 变量名称：discriminator/image_domain/d_h3_conv/Conv/weights:0, 形状：(3, 3, 256, 512), 参数数量：1179648
# 变量名称：discriminator/image_domain/d_h3_conv/Conv/biases:0, 形状：(512,), 参数数量：512
# 变量名称：discriminator/image_domain/d_h4_pred/Conv/weights:0, 形状：(3, 3, 512, 1), 参数数量：4608
# 变量名称：discriminator/image_domain/d_h4_pred/Conv/biases:0, 形状：(1,), 参数数量：1
# 变量名称：loss/smoothing/gauss_weight:0, 形状：(11, 11, 1, 1), 参数数量：121
# 变量名称：loss/smoothing_1/gauss_weight:0, 形状：(11, 11, 1, 1), 参数数量：121
# 模型中可训练变量的总数量： 2935778

# %%
variable_count('../checkpoint/xfer_complete_frompred_MIL/model.ckpt-6700.meta')
# Out:
# 变量名称：conv2d/kernel:0, 形状：(3, 3, 1, 32), 参数数量：288
# 变量名称：conv2d/bias:0, 形状：(32,), 参数数量：32
# 变量名称：conv2d_1/kernel:0, 形状：(3, 3, 32, 64), 参数数量：18432
# 变量名称：conv2d_1/bias:0, 形状：(64,), 参数数量：64
# 变量名称：conv2d_2/kernel:0, 形状：(1, 1, 64, 34), 参数数量：2176
# 变量名称：conv2d_2/bias:0, 形状：(34,), 参数数量：34
# 模型中可训练变量的总数量： 21026
